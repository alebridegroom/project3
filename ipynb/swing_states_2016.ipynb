# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
 # Import our data into pandas from CSV
file_path = '2016 margins.csv'
library_usage_df = pd.read_csv(file_path, low_memory=False)

library_usage_df
# Out:
#                    state called final   dem_votes   rep_votes other_votes  \
# 0             U.S. Total      D   Yes  81,282,916  74,223,369   2,891,441
# 1   15 Key Battlegrounds    NaN   NaN  31,908,248  33,002,287     950,354
# 2      Non-Battlegrounds    NaN   NaN  49,374,668  41,221,082   1,941,087
# 3   15 Key Battlegrounds    NaN   NaN         NaN         NaN         NaN
# 4                Arizona      D   Yes   1,672,143   1,661,686      53,497
# ..                   ...    ...   ...         ...         ...         ...
# 56               Vermont      D   Yes     242,820     112,704      11,904
# 57              Virginia      D   Yes   2,413,568   1,962,430      84,526
# 58            Washington      D   Yes   2,369,612   1,584,651     133,368
# 59         West Virginia      R   Yes     235,984     545,382      13,286
# 60               Wyoming      R   Yes      73,491     193,559       9,715
#
#    dem_percent rep_percent other_percent dem_this_margin  ... stateid    EV  \
# ...

# %%
election_2016.dtypes
# Out:
# state                object
# called               object
# final                object
# dem_votes            object
# rep_votes            object
# other_votes          object
# dem_percent          object
# rep_percent          object
# other_percent        object
# dem_this_margin      object
# margin_shift         object
# vote_change          object
# stateid              object
# EV                  float64
# X                   float64
# Y                   float64
# State_num           float64
# Center_X            float64
# Center_Y            float64
# Unnamed: 19         float64
# 2016 Margin         float64
# Total 2016 Votes     object
# dtype: object

# %%
dropped_rows = election_2016.iloc[4:]
dropped_rows
# Out:
#                     state called final   dem_votes  rep_votes other_votes  \
# 4                 Arizona      D   Yes   1,672,143  1,661,686      53,497
# 5                 Florida      R   Yes   5,297,045  5,668,731     101,680
# 6                 Georgia      D   Yes   2,473,633  2,461,854      62,229
# 7                    Iowa      R   Yes     759,061    897,672      34,138
# 8      Maine 2nd District      R   Yes     168,696    196,692      10,961
# 9                Michigan      D   Yes   2,804,040  2,649,852      85,410
# 10              Minnesota      D   Yes   1,717,077  1,484,065      76,029
# 11  Nebraska 2nd District      D   Yes     176,468    154,377       6,909
# 12                 Nevada      D   Yes     703,486    669,890      32,000
# 13          New Hampshire      D   Yes     424,921    365,654      15,607
# 14         North Carolina      R   Yes   2,684,292  2,758,775      81,737
# 15                   Ohio      R   Yes   2,679,165  3,154,834      88,203
# ...

# %%
swing_states = dropped_rows.iloc[:-42]
swing_states
# Out:
#                     state called final  dem_votes  rep_votes other_votes  \
# 4                 Arizona      D   Yes  1,672,143  1,661,686      53,497
# 5                 Florida      R   Yes  5,297,045  5,668,731     101,680
# 6                 Georgia      D   Yes  2,473,633  2,461,854      62,229
# 7                    Iowa      R   Yes    759,061    897,672      34,138
# 8      Maine 2nd District      R   Yes    168,696    196,692      10,961
# 9                Michigan      D   Yes  2,804,040  2,649,852      85,410
# 10              Minnesota      D   Yes  1,717,077  1,484,065      76,029
# 11  Nebraska 2nd District      D   Yes    176,468    154,377       6,909
# 12                 Nevada      D   Yes    703,486    669,890      32,000
# 13          New Hampshire      D   Yes    424,921    365,654      15,607
# 14         North Carolina      R   Yes  2,684,292  2,758,775      81,737
# 15                   Ohio      R   Yes  2,679,165  3,154,834      88,203
# ...

# %%
swing_2016 = swing_states[["state","dem_votes","rep_votes","other_votes","dem_percent","rep_percent","other_percent","2016 Margin","Total 2016 Votes"]]
swing_2016
# Out:
#                     state  dem_votes  rep_votes other_votes dem_percent  \
# 4                 Arizona  1,672,143  1,661,686      53,497      49.40%
# 5                 Florida  5,297,045  5,668,731     101,680      47.90%
# 6                 Georgia  2,473,633  2,461,854      62,229      49.50%
# 7                    Iowa    759,061    897,672      34,138      44.90%
# 8      Maine 2nd District    168,696    196,692      10,961      44.80%
# 9                Michigan  2,804,040  2,649,852      85,410      50.60%
# 10              Minnesota  1,717,077  1,484,065      76,029      52.40%
# 11  Nebraska 2nd District    176,468    154,377       6,909      52.20%
# 12                 Nevada    703,486    669,890      32,000      50.10%
# 13          New Hampshire    424,921    365,654      15,607      52.70%
# 14         North Carolina  2,684,292  2,758,775      81,737      48.60%
# 15                   Ohio  2,679,165  3,154,834      88,203      45.20%
# ...

# %%
swing_2016.to_json('file.json', orient = 'split', compression = 'infer', index = 'true')

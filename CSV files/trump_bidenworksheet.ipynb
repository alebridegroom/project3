# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Name of the CSV file
trump_bidencsv = Path('uncleaned/trump_biden_polls.csv')

# %%
# The correct encoding must be used to read the CSV in pandas
trump_bidendf = pd.read_csv(trump_bidencsv, encoding="UTF-8")
# Out:
# C:\Users\lifeo\AppData\Local\Temp\ipykernel_14564\769977790.py:2: DtypeWarning: Columns (6,22,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   trump_bidendf = pd.read_csv(trump_bidencsv, encoding="UTF-8")

# %%
trump_bidendf.head()
# Out:
#    question_id  poll_id  cycle         state  pollster_id  \
# 0       136283    72621   2020          Iowa          383
# 1       136283    72621   2020          Iowa          383
# 2       136322    72647   2020  Pennsylvania          461
# 3       136322    72647   2020  Pennsylvania          461
# 4       136322    72647   2020  Pennsylvania          461
#
#                               pollster sponsor_ids sponsors  \
# 0                Public Policy Polling         NaN      NaN
# 1                Public Policy Polling         NaN      NaN
# 2  Susquehanna Polling & Research Inc.         NaN      NaN
# 3  Susquehanna Polling & Research Inc.         NaN      NaN
# 4  Susquehanna Polling & Research Inc.         NaN      NaN
#
#                           display_name  pollster_rating_id  ...  \
# 0                Public Policy Polling               263.0  ...
# 1                Public Policy Polling               263.0  ...
# ...

# %%
cleantrump_bidendf = trump_bidendf[['cycle', 'state', 'stage', 'answer', 'candidate_name', 'candidate_party', 'pct']]
cleantrump_bidendf.head()
# Out:
#    cycle         state    stage     answer       candidate_name  \
# 0   2020          Iowa  general      Biden  Joseph R. Biden Jr.
# 1   2020          Iowa  general      Trump         Donald Trump
# 2   2020  Pennsylvania  general      Biden  Joseph R. Biden Jr.
# 3   2020  Pennsylvania  general      Trump         Donald Trump
# 4   2020  Pennsylvania  general  Jorgensen         Jo Jorgensen
#
#   candidate_party   pct
# 0             DEM  49.0
# 1             REP  48.0
# 2             DEM  48.4
# 3             REP  49.2
# 4             LIB   1.4

# %%
cleantrump_bidendf.to_csv("cleaned/trump_bidenclean.csv", index=False, encoding="UTF-8")
